# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('KPMG newCustomerList dataset.xlsx')
df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Morly    Brister    Male                                   86
# 1    Ardelis     Genery    Male                                   69
# 2     Lucine  Forrester  Female                                   10
# 3    Melinda      Stutt  Female                                   64
# 4      Druci     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
df.isnull().sum()
# Out:
# first_name                               1
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
dd=df['DOB']
dm=dd.mode()
dm.mean()
# Out:
# Timestamp('1971-09-30 07:40:48')

# %%
du=df['DOB']
nw=[]
for i in do:
    k=str(i)
    nw.append(k)
sq=[]
nw
for j in nw:
    if j == 'NaT':
        sq.append('1971')
    else:
        sq.append(j[0:4])
dt=[]
for q in sq:
    we=int(q)
    dt.append(we)

# %%
gn=[]
for t in dt:
    gn.append(2021-t)

# %%
gh=df['DOB']
fn=df['DOB']
s=0
for i in fn:
    gh = gh.replace([i], [gn[s]])
    s = s+1
s=0
for i in fn:
    df['DOB'] = df['DOB'].replace([i], [gn[s]])
    s = s+1
df=df.rename(columns={"DOB":"AGE"})
df
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  AGE  \
# 0        Morly    Brister    Male                                   86   64
# 1      Ardelis     Genery    Male                                   69   51
# 2       Lucine  Forrester  Female                                   10   47
# 3      Melinda      Stutt  Female                                   64   42
# 4        Druci     Hadlee  Female                                   34   56
# ..         ...        ...     ...                                  ...  ...
# 995       Burk  Romanetti    Male                                   60   62
# 996   Melloney    Wortley    Male                                   22   20
# 997     Dickie      Temby  Female                                   17   67
# 998      Sylas    Cubbini    Male                                   30   69
# 999        NaN    Duffill    Male                                   56   66
#
# ...

# %%
df[['first_name']]=df[['first_name']].fillna(value='Duffill')
f=df
u=f[f['job_industry_category'].isnull()]
u
# Out:
#     first_name last_name  gender  past_3_years_bike_related_purchases  AGE  \
# 22    Tabbatha     Ottey    Male                                   26   23
# 23       Brena   Averill  Female                                    5   44
# 33      Maisie    McNess    Male                                   71   40
# 36    Mitchell   Petford    Male                                   76   53
# 43      Brooke    Suggey  Female                                   52   55
# ..         ...       ...     ...                                  ...  ...
# 959      Sonia   Dibdall  Female                                   62   54
# 971    Ellwood   Tavinor  Female                                   43   22
# 975       Esme    Bodega    Male                                   63   53
# 980      Leona   Anshell  Female                                   71   29
# 983    Pauline     Munns  Female                                    5   70
#
# ...

# %%
m=f['job_industry_category'].mode()
m
# Out:
# 0    Financial Services
# dtype: object

# %%
v=f['job_title']
v.describe()
# Out:
# count                     894
# unique                    184
# top       Associate Professor
# freq                       15
# Name: job_title, dtype: object

# %%
f[['job_industry_category']]=f[['job_industry_category']].fillna(value='Financial Services')
f=df.drop(columns=['last_name', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'deceased_indicator','job_title'])
f
# Out:
#     first_name  gender  past_3_years_bike_related_purchases  AGE  \
# 0        Morly    Male                                   86   64
# 1      Ardelis    Male                                   69   51
# 2       Lucine  Female                                   10   47
# 3      Melinda  Female                                   64   42
# 4        Druci  Female                                   34   56
# ..         ...     ...                                  ...  ...
# 995       Burk    Male                                   60   62
# 996   Melloney    Male                                   22   20
# 997     Dickie  Female                                   17   67
# 998      Sylas    Male                                   30   69
# 999    Duffill    Male                                   56   66
#
#     job_industry_category     wealth_segment owns_car  tenure  \
# 0           Manufacturing      Mass Customer      Yes      14
# ...

# %%
g=f['AGE']
g.describe()
# Out:
# count    1000.000000
# mean       50.203000
# std        16.928389
# min        19.000000
# 25%        38.750000
# 50%        50.000000
# 75%        64.000000
# max        83.000000
# Name: AGE, dtype: float64

# %%
gt=f[df['AGE'] <= 38]
fi=gt['past_3_years_bike_related_purchases'].sum()

# %%
ran=[]
di=[[0,19],[19,38],[38,44],[44,50],[50,57],[57,64],[64,74],[74,84]]
for d in di:
    gt=df[df['AGE'] <= d[1]]
    gt=gt[gt['AGE'] > d[0]]
    fi=gt['past_3_years_bike_related_purchases'].sum()
    ran.append(fi)
ran
# Out:
# [177, 12547, 5670, 7768, 6547, 5799, 7111, 4217]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ra=ran
age=['0-19','20-38','39-44','44-50','51-57','57-64','65-74','75-84']
plt.ylabel('sumes_past_three_years_bike_related_purchas')
plt.xlabel('Age range')
plt.bar(age,ra)
# Out:
# <BarContainer object of 8 artists>

# %%
ra=ran
age=['0-19','20-38','39-44','44-50','51-57','57-64','65-74','75-84']
color=['r','g','b','m','y','p','o','r']
plt.pie(ra,labels=age,shadow=True,startangle=90,explode=(0.3,0.1,0,0,0,0,0,0.2))
plt.show()

# %%
n=f
y=n[n['AGE'] <= 50]
y=y[y['AGE'] > 19]
ya=y[y['owns_car']=='No']
ye=y[y['owns_car']=='Yes']
gar=['Yes','No']
rga=[len(ye),len(ya)]
plt.title('Number of people within 20-50 years who own car')
plt.bar(gar,rga)
# Out:
# <BarContainer object of 2 artists>

# %%
grr=ya['past_3_years_bike_related_purchases'].sum()
grt=ye['past_3_years_bike_related_purchases'].sum()
gar=['Yes','No']
rga=[grt,grr]
plt.title('Number of people within 20-50 years bike purchases')
plt.bar(gar,rga)
# Out:
# <BarContainer object of 2 artists>

# %%
n=f
y=n[n['AGE'] <= 50]
y=y[y['AGE'] > 19]
y=y[y['owns_car']=='No']
y
# Out:
#     first_name  gender  past_3_years_bike_related_purchases  AGE  \
# 2       Lucine  Female                                   10   47
# 6       Nancie    Male                                   23   45
# 10     Wheeler    Male                                   94   26
# 11        Olag    Male                                   48   22
# 12       Melba    Male                                   60   31
# ..         ...     ...                                  ...  ...
# 971    Ellwood  Female                                   43   22
# 985   Consalve  Female                                   83   34
# 987       Vyky  Female                                   44   24
# 994  Ferdinand  Female                                   15   31
# 996   Melloney    Male                                   22   20
#
#     job_industry_category     wealth_segment owns_car  tenure  \
# 2      Financial Services  Affluent Customer       No      10
# ...

# %%
uw=y[y['wealth_segment']=='Mass Customer']
uw=uw.drop(columns=['tenure','Value','Rank','property_valuation','country'])
st=uw[uw['state']=='NSW']
jo=st[st['job_industry_category']=='Financial Services']

# %%
jo
# Out:
#     first_name  gender  past_3_years_bike_related_purchases  AGE  \
# 6       Nancie    Male                                   23   45
# 71      Kevina  Female                                   78   27
# 82      Gardie  Female                                   14   40
# 121      Teddy    Male                                   57   24
# 204    Corrine    Male                                    2   23
# 216       Cami  Female                                   50   24
# 250     Shadow  Female                                   90   46
# 366      Gerik  Female                                   84   50
# 417    Salomon  Female                                   46   32
# 419    Queenie  Female                                   33   30
# 454    Laurena    Male                                   70   36
# 498     Renell  Female                                   56   32
# 510     Jammal    Male                                    4   48
# ...

# %%
target_customers=jo.drop(columns=['past_3_years_bike_related_purchases'])
target_customers
# Out:
#     first_name  gender  AGE job_industry_category wealth_segment owns_car  \
# 6       Nancie    Male   45    Financial Services  Mass Customer       No
# 71      Kevina  Female   27    Financial Services  Mass Customer       No
# 82      Gardie  Female   40    Financial Services  Mass Customer       No
# 121      Teddy    Male   24    Financial Services  Mass Customer       No
# 204    Corrine    Male   23    Financial Services  Mass Customer       No
# 216       Cami  Female   24    Financial Services  Mass Customer       No
# 250     Shadow  Female   46    Financial Services  Mass Customer       No
# 366      Gerik  Female   50    Financial Services  Mass Customer       No
# 417    Salomon  Female   32    Financial Services  Mass Customer       No
# 419    Queenie  Female   30    Financial Services  Mass Customer       No
# 454    Laurena    Male   36    Financial Services  Mass Customer       No
# 498     Renell  Female   32    Financial Services  Mass Customer       No
# ...
